# %% [markdown]
# <a href="https://colab.research.google.com/github/tuanha2002/HudRelay-2.0/blob/main/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# if [ ! -d "GPT-SoVITS" ]; then
#     git clone https://github.com/RVC-Boss/GPT-SoVITS.git
# fi
#
# cd GPT-SoVITS
#
# mkdir -p GPT_weights
#
# mkdir -p SoVITS_weights
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# # Modify install.sh to force gradio version 3.41.2
# sed -i 's/gradio/gradio==3.41.2/g' install.sh
# bash install.sh --device CU126 --source HF
# Out:
# Overwriting /content/setup.sh

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2025.12-2-Linux-x86_64.sh")
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ✨🍰✨ Everything looks OK!

# %%
# !bash setup.sh
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# bash: /usr/local/lib/libtinfo.so.6: no version information available (required by bash)
# ...
# bash: /usr/local/lib/libtinfo.so.6: no version information available (required by bash)
# [INFO]: Detected system: Linux 6.6.113+ x86_64
# [INFO]: Detected GCC Version: 11
# [INFO]: Skip Installing GCC & G++ From Conda-Forge
# [INFO]: Installing libstdcxx-ng From Conda-Forge
# [SUCCESS]: libstdcxx-ng=11 Installed...
# [INFO]: Installing FFmpeg & CMake...
# [SUCCESS]: FFmpeg & CMake Installed
# [INFO]: Installing unzip...
# [SUCCESS]: unzip Installed
# [INFO]: Download Model From HuggingFace
# [INFO]: Pretrained Model Exists
# [INFO]: Skip Downloading Pretrained Models
# [INFO]: G2PWModel Exists
# [INFO]: Skip Downloading G2PWModel
# [INFO]: Checking For Nvidia Driver Installation...
# \033[INFO]: \033Nvidia Driver Founded
# [INFO]: Installing PyTorch For CUDA 12.6...
# ...

# %%
# !source activate GPTSoVITS && pip install "pydantic<2" "gradio==3.41.2"
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...

# %%
# !source activate GPTSoVITS && pip install torch==2.1.2+cu121 torchaudio==2.1.2+cu121 --index-url https://download.pytorch.org/whl/cu121
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 GB 10.2 MB/s  0:00:58
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 107.1 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 59.5 MB/s  0:00:01
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0+cu126
#     Uninstalling torch-2.11.0+cu126:
#       Successfully uninstalled torch-2.11.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.11.0
#     Uninstalling torchaudio-2.11.0:
#       Successfully uninstalled torchaudio-2.11.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchaudio]
# ...

# %%
# Modify These
USER_ID = "aihobbyist"
REPO_NAME = "GPT-SoVits-V2-models"
BRANCH = "master"
GPT_PATH = "Genshin_Impact/EN/GPT_GenshinImpact_EN_5.1.ckpt"
SOVITS_PATH = "Wuthering_Waves/CN/SV_WutheringWaves_CN_1.3.pth"

# Do Not Modify
HF_BASE = "https://www.modelscope.cn/models"
REPO_ID = f"{USER_ID}/{REPO_NAME}"
GPT_URL = f"{HF_BASE}/{REPO_ID}/resolve/{BRANCH}/{GPT_PATH}"
SOVITS_URL = f"{HF_BASE}/{REPO_ID}/resolve/{BRANCH}/{SOVITS_PATH}"

# !cd "/content/GPT-SoVITS/GPT_weights" && wget "{GPT_URL}"
# !cd "/content/GPT-SoVITS/SoVITS_weights" && wget "{SOVITS_URL}"
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2026-05-07 15:05:48--  https://www.modelscope.cn/models/aihobbyist/GPT-SoVits-V2-models/resolve/master/Genshin_Impact/EN/GPT_GenshinImpact_EN_5.1.ckpt
# Resolving www.modelscope.cn (www.modelscope.cn)... 47.251.62.57
# Connecting to www.modelscope.cn (www.modelscope.cn)|47.251.62.57|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-cn-1.modelscope.cn/prod/lfs-objects/e6/cb/c66e3dc4c566cb3cdfbb5dc51189390503cba4125801f606f4be918e8e76?filename=GPT_GenshinImpact_EN_5.1.ckpt&namespace=aihobbyist&repository=GPT-SoVits-V2-models&revision=master&tag=model&auth_key=1778166348-8db08599541e46298bd9b8ee0a48740e-0-7f51f36dc71d29938e69d767f0833324 [following]
# ...

# %%
# Modify These
USER_ID = "tuannho28"
REPO_NAME = "GPT-sovits"
BRANCH = "main"
GPT_PATH = "nam-60-e15.ckpt"
SOVITS_PATH = "nam-60_e15_s2535_l32.pth"

# Do Not Modify
HF_BASE = "https://huggingface.co"
REPO_ID = f"{USER_ID}/{REPO_NAME}"
GPT_URL = f"{HF_BASE}/{REPO_ID}/blob/{BRANCH}/{GPT_PATH}"
SOVITS_URL = f"{HF_BASE}/{REPO_ID}/blob/{BRANCH}/{SOVITS_PATH}"

# !cd "/content/GPT-SoVITS/GPT_weights" && wget "{GPT_URL}"
# !cd "/content/GPT-SoVITS/SoVITS_weights" && wget "{SOVITS_URL}"
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2026-05-07 14:29:17--  https://huggingface.co/tuannho28/GPT-sovits/blob/main/nam-60-e15.ckpt
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.23, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.55|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51513 (50K) [text/html]
# Saving to: ‘nam-60-e15.ckpt’
#
# nam-60-e15.ckpt     100%[===================>]  50.31K  --.-KB/s    in 0.01s
#
# 2026-05-07 14:29:17 (4.83 MB/s) - ‘nam-60-e15.ckpt’ saved [51513/51513]
#
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2026-05-07 14:29:17--  https://huggingface.co/tuannho28/GPT-sovits/blob/main/nam-60_e15_s2535_l32.pth
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.23, 18.164.174.118, ...
# ...

# %%
inference_file = "/content/GPT-SoVITS/GPT_SoVITS/inference_webui.py"

# Sử dụng Python để thay thế chính xác nội dung file
with open(inference_file, 'r', encoding='utf-8') as f:
    content = f.read()

# Thay thế triệt để dict_s2['data']['sampling_rate']
new_content = content.replace("dict_s2['data']['sampling_rate']", "hps.data.sampling_rate")
# Thay thế vq_model
new_content = new_content.replace("vq_model.extract_latent", "vqvae_model.extract_latent")

with open(inference_file, 'w', encoding='utf-8') as f:
    f.write(new_content)

# Kiểm tra lại xem còn từ khóa dict_s2 không
# !grep "dict_s2" {inference_file} || echo "Đã dọn dẹp sạch dict_s2!"
print('Bản vá đã được ghi đè trực tiếp. Hãy chạy lại cell WebUI (W3R9tp2GzvbW).')
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#     dict_s2 = load_sovits_new(sovits_path)
#     hps = dict_s2["config"]
#     if "enc_p.text_embedding.weight" not in dict_s2["weight"]:
#     elif dict_s2["weight"]["enc_p.text_embedding.weight"].shape[0] == 322:
#         print("loading sovits_%s" % model_version, vq_model.load_state_dict(dict_s2["weight"], strict=False))
#         lora_rank = dict_s2["lora_rank"]
#         vq_model.load_state_dict(dict_s2["weight"], strict=False)
# Bản vá đã được ghi đè trực tiếp. Hãy chạy lại cell WebUI (W3R9tp2GzvbW).

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
